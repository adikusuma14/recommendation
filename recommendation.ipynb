# %%
import pandas as pd #for manipulate data using dataframe
import numpy as np #for some arithmetic

# %%
df = pd.read_csv('electronics.csv') #read dataset format .csv
df.sample(10)#sample 10 data random from variable df as dataframe
# Out:
#          item_id  user_id  rating   timestamp   model_attr  \
# 451299      5940   415668     4.0  2015-03-03  Female&Male
# 1183902     4736  1061056     5.0  2017-10-23       Female
# 986975      7435   887408     5.0  2016-11-16       Female
# 649900      5070   591771     1.0  2015-10-22       Female
# 923983      2031   832200     3.0  2016-08-18       Female
# 220313      2205   207315     4.0  2014-01-07  Female&Male
# 292876      4037   273824     5.0  2014-07-14       Female
# 1121730     4152  1006290     1.0  2017-06-09         Male
# 604402      2624   551570     5.0  2015-09-02       Female
# 83808       1577    79929     4.0  2012-03-01         Male
#
#                         category      brand  year user_attr  split
# 451299    Portable Audio & Video        NaN  2015       NaN      0
# 1183902               Home Audio        NaN  2014       NaN      0
# 986975   Computers & Accessories        NaN  2015       NaN      0
# ...

# %%
print("Number of rows"+" "+str(df.shape[0]), "Number of columns"+" "+str(df.shape[1]))
# Out:
# Number of rows 1292954 Number of columns 10
